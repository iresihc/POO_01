# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd


d=pd.read_csv("/content/drive/MyDrive/Programación /ETF prices.csv")
d
# Out:
#         fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0               AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1               AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2               AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3               AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4               AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100
# ...             ...         ...    ...    ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  27.21  26.30  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.96  26.57  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  28.14  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.56  27.80  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.73  25.91  28.49      28.49  219400
#
# ...

# %%
import numpy as np

precios=np.random.rand(10)

closed=np.random.randint(1,100,10)

# %%
closed
# Out:
# array([92, 16, 38, 12, 78, 65, 72, 74, 92, 54])

# %%
diccionario={"Precios":precios,
             "Cierre":closed}
precio=pd.DataFrame(diccionario)
precio
# Out:
#     Precios  Cierre
# 0  0.632931      92
# 1  0.132722      16
# 2  0.465885      38
# 3  0.617773      12
# 4  0.897976      78
# 5  0.749681      65
# 6  0.547273      72
# 7  0.844138      74
# 8  0.985062      92
# 9  0.445003      54

# %%
precio[precio["Cierre"]>70]
# Out:
#     Precios  Cierre
# 0  0.632931      92
# 4  0.897976      78
# 6  0.547273      72
# 7  0.844138      74
# 8  0.985062      92

# %%
d.shape
# Out:
# (3866030, 8)

# %%
d.ndim
# Out:
# 2

# %%
d.drop(columns=["high", "low"])
# Out:
#         fund_symbol  price_date   open  close  adj_close  volume
# 0               AAA  2020-09-09  25.10  25.07      24.85   17300
# 1               AAA  2020-09-10  25.06  25.07      24.85   23500
# 2               AAA  2020-09-11  25.04  25.03      24.81   33400
# 3               AAA  2020-09-14  25.01  25.02      24.80   13100
# 4               AAA  2020-09-15  25.02  25.01      24.79   12100
# ...             ...         ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.49      28.49  219400
#
# [3866030 rows x 6 columns]

# %%
d.iloc[0:100]
# Out:
#    fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0          AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1          AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2          AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3          AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4          AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100
# ..         ...         ...    ...    ...    ...    ...        ...     ...
# 95         AAA  2021-01-26  25.16  25.17  25.16  25.17      25.02     500
# 96         AAA  2021-01-27  25.14  25.15  25.14  25.15      25.01     500
# 97         AAA  2021-01-28  25.15  25.15  25.15  25.15      25.01     200
# 98         AAA  2021-01-29  25.16  25.16  25.15  25.15      25.00    3100
# 99         AAA  2021-02-01  25.14  25.14  25.13  25.13      25.01    1300
#
# [100 rows x 8 columns]

# %%
d.iloc[:,[1,2,5]]
# Out:
#          price_date   open  close
# 0        2020-09-09  25.10  25.07
# 1        2020-09-10  25.06  25.07
# 2        2020-09-11  25.04  25.03
# 3        2020-09-14  25.01  25.02
# 4        2020-09-15  25.02  25.01
# ...             ...    ...    ...
# 3866025  2021-11-23  26.81  26.35
# 3866026  2021-11-24  26.79  26.69
# 3866027  2021-11-26  26.67  27.72
# 3866028  2021-11-29  27.89  28.27
# 3866029  2021-11-30  28.15  28.49
#
# [3866030 rows x 3 columns]

# %%
d["open"].value_counts()
# Out:
# 25.00       3491
# 26.00       2724
# 25.10       2678
# 25.50       2570
# 25.25       2401
#             ...
# 68700.00       1
# 68780.00       1
# 68260.00       1
# 65560.00       1
# 224.38         1
# Name: open, Length: 75068, dtype: int64

# %%
d.describe()
# Out:
#                open          high           low         close     adj_close  \
# count  3.866030e+06  3.866030e+06  3.866030e+06  3.866030e+06  3.866030e+06
# mean   1.202537e+05  1.262811e+05  1.149734e+05  1.196726e+05  1.196579e+05
# std    1.149917e+07  1.208270e+07  1.097204e+07  1.143655e+07  1.143655e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.486000e+01  2.494000e+01  2.476000e+01  2.485000e+01  2.229000e+01
# 50%    3.388000e+01  3.406000e+01  3.368000e+01  3.387000e+01  3.108000e+01
# 75%    5.417000e+01  5.441000e+01  5.390000e+01  5.416000e+01  5.007000e+01
# max    2.656750e+09  2.808750e+09  2.609750e+09  2.808750e+09  2.808750e+09
#
#              volume
# count  3.866030e+06
# mean   1.026745e+06
# std    1.275733e+07
# min    0.000000e+00
# 25%    3.553000e+03
# 50%    2.133900e+04
# 75%    1.269000e+05
# max    2.987062e+09

# %%
e=d.drop(columns=["high", "low"])
e
# Out:
#         fund_symbol  price_date   open  close  adj_close  volume
# 0               AAA  2020-09-09  25.10  25.07      24.85   17300
# 1               AAA  2020-09-10  25.06  25.07      24.85   23500
# 2               AAA  2020-09-11  25.04  25.03      24.81   33400
# 3               AAA  2020-09-14  25.01  25.02      24.80   13100
# 4               AAA  2020-09-15  25.02  25.01      24.79   12100
# ...             ...         ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.49      28.49  219400
#
# [3866030 rows x 6 columns]

# %%
e.drop(columns=["fund_symbol"])
# Out:
#          price_date   open  close  adj_close  volume
# 0        2020-09-09  25.10  25.07      24.85   17300
# 1        2020-09-10  25.06  25.07      24.85   23500
# 2        2020-09-11  25.04  25.03      24.81   33400
# 3        2020-09-14  25.01  25.02      24.80   13100
# 4        2020-09-15  25.02  25.01      24.79   12100
# ...             ...    ...    ...        ...     ...
# 3866025  2021-11-23  26.81  26.35      26.35  190900
# 3866026  2021-11-24  26.79  26.69      26.69  109000
# 3866027  2021-11-26  26.67  27.72      27.72  205500
# 3866028  2021-11-29  27.89  28.27      28.27  411900
# 3866029  2021-11-30  28.15  28.49      28.49  219400
#
# [3866030 rows x 5 columns]

# %%
e.mean(axis=1)
# Out:
# <ipython-input-19-070da3450c40>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   e.mean(axis=1)
# 0            4343.7550
# 1            5893.7450
# 2            8368.7200
# 3            3293.7075
# 4            3043.7050
#               ...
# 3866025     47744.8775
# 3866026     27270.0425
# 3866027     51395.5275
# 3866028    102996.1075
# 3866029     54871.2825
# Length: 3866030, dtype: float64
